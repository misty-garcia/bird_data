# %%
import pandas as pd
import numpy as np

import os

# %%
files = os.listdir('data')
files.sort()
files = files[1:-1]
files
# Out:
# ['ebd_US-TX-013_relDec-2023.txt',
#  'ebd_US-TX-019_relDec-2023.txt',
#  'ebd_US-TX-029_relDec-2023.txt',
#  'ebd_US-TX-091_relDec-2023.txt',
#  'ebd_US-TX-171_relDec-2023.txt',
#  'ebd_US-TX-187_relDec-2023.txt',
#  'ebd_US-TX-259_relDec-2023.txt',
#  'ebd_US-TX-265_relDec-2023.txt',
#  'ebd_US-TX-325_relDec-2023.txt',
#  'ebd_US-TX-493_relDec-2023.txt']

# %%
def clean_ebird(df_init):
    
    #make it python friendly
    df_init.columns = df_init.columns.str.lower().str.replace('\W+','_',regex=True)

    #remove unnecessary columns
    df_init = df_init.drop(columns=['global_unique_identifier','last_edited_date','taxon_concept_id',
                                    'scientific_name','subspecies_common_name','subspecies_scientific_name',
                                    'exotic_code','breeding_code','breeding_category','behavior_code',
                                    'age_sex','country','country_code','state_code','state',
                                    'county_code','iba_code','bcr_code', 'locality_id', 'locality_type',
                                    'protocol_code','protocol_type', 'project_code','effort_area_ha',
                                    'has_media','approved','reviewed','reason','trip_comments',
                                    'species_comments','unnamed_49','usfws_code','atlas_block',])

    #replace all Xs with 1s, to count the bird once
    df_init.observation_count = np.where(df_init.observation_count == 'X', 1, df_init.observation_count)
    df_init.observation_count = df_init.observation_count.astype(int)

    #find all dupe checklists
    #sort them by observation count
    #drop the duplicates, except teh first instance
    df_keep_dups = df_init [df_init.group_identifier.notnull()].sort_values('observation_count', 
                                                   ascending=False).drop_duplicates(subset=['taxonomic_order',
                                                                                            'group_identifier'])
    #remove all duplicate checklists completely
    df_no_dups = df_init [df_init.group_identifier.isnull()]


    #combine the no dups df with the first dups only df
    df = pd.concat([df_no_dups, df_keep_dups])

    #drop group identifier column, as its no longer needed
    df = df.drop('group_identifier', axis=1)

    #remove everything before 2002
    df = df [df.observation_date >= '2002-01-01']

    return df

# %%
clean_dfs = []

for file in files:
    print(file)
    df = pd.read_csv('data/' + file, sep='\t')
    clean_df = clean_ebird(df)
    clean_dfs.append(clean_df)
# Out:
# ebd_US-TX-013_relDec-2023.txt
# ebd_US-TX-019_relDec-2023.txt
# /var/folders/14/ft4ch4ld42z46kvx0_wfd3d40000gp/T/ipykernel_1615/71692512.py:5: DtypeWarning: Columns (11,12,13,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/' + file, sep='\t')
# ebd_US-TX-029_relDec-2023.txt
# /var/folders/14/ft4ch4ld42z46kvx0_wfd3d40000gp/T/ipykernel_1615/71692512.py:5: DtypeWarning: Columns (11,12,13,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/' + file, sep='\t')
# ebd_US-TX-091_relDec-2023.txt
# ebd_US-TX-171_relDec-2023.txt
# ebd_US-TX-187_relDec-2023.txt
# /var/folders/14/ft4ch4ld42z46kvx0_wfd3d40000gp/T/ipykernel_1615/71692512.py:5: DtypeWarning: Columns (11,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/' + file, sep='\t')
# ebd_US-TX-259_relDec-2023.txt
# /var/folders/14/ft4ch4ld42z46kvx0_wfd3d40000gp/T/ipykernel_1615/71692512.py:5: DtypeWarning: Columns (11,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/' + file, sep='\t')
# ebd_US-TX-265_relDec-2023.txt
# ebd_US-TX-325_relDec-2023.txt
# ebd_US-TX-493_relDec-2023.txt

# %%
dff = pd.concat(clean_dfs)
dff = dff.reset_index(drop=True)

# %%
dff.head()
# Out:
#    taxonomic_order category                   common_name  observation_count  \
# 0            11791  species              American Kestrel                  1
# 1              233  species  Black-bellied Whistling-Duck                 12
# 2            33307  species          Brown-headed Cowbird                  1
# 3            33325  species            Brewer's Blackbird                  1
# 4             8416  species                      Barn Owl                  1
#
#      county                           locality   latitude  longitude  \
# 0  Atascosa                        Peeler Tank  28.735340 -98.435998
# 1  Atascosa                        Peeler Tank  28.735340 -98.435998
# 2  Atascosa  Atascosa Co.--CR411/412 FM99 area  28.710839 -98.214340
# 3  Atascosa  Atascosa Co.--CR411/412 FM99 area  28.710839 -98.214340
# 4  Atascosa                        Peeler Tank  28.735340 -98.435998
#
#   observation_date time_observations_started observer_id  \
# 0       2002-01-05                       NaN   obsr88598
# 1       2002-01-05                       NaN   obsr88598
# 2       2002-01-11                  14:35:00   obsr21142
# 3       2002-01-11                  14:35:00   obsr21142
# 4       2002-01-05                       NaN   obsr88598
#
#   sampling_event_identifier  duration_minutes  effort_distance_km  \
# 0                  S5554748               NaN                 NaN
# 1                  S5554748               NaN                 NaN
# 2                 S17226909              50.0               1.609
# 3                 S17226909              50.0               1.609
# 4                  S5554748               NaN                 NaN
#
#    number_observers  all_species_reported
# 0               NaN                     1
# 1               NaN                     1
# 2               2.0                     1
# 3               2.0                     1
# 4               NaN                     1

# %%
dff.shape
# Out:
# (3626211, 16)

# %%
dff.county.value_counts()
# Out:
# Bexar        1765735
# Guadalupe     396980
# Kendall       372021
# Comal         311381
# Kerr          283787
# Bandera       232628
# Wilson         77269
# Medina         75427
# Gillespie      72553
# Atascosa       38430
# Name: county, dtype: int64

# %%
dff.to_csv('ebird_all_BAS.csv')

# %%
dff
# Out:
#          taxonomic_order category                   common_name  \
# 0                  11791  species              American Kestrel
# 1                    233  species  Black-bellied Whistling-Duck
# 2                  33307  species          Brown-headed Cowbird
# 3                  33325  species            Brewer's Blackbird
# 4                   8416  species                      Barn Owl
# ...                  ...      ...                           ...
# 3626206            34060  species                Indigo Bunting
# 3626207            34060  species                Indigo Bunting
# 3626208             5798  species                      Killdeer
# 3626209             5798  species                      Killdeer
# 3626210             5798  species                      Killdeer
#
#          observation_count    county  \
# 0                        1  Atascosa
# 1                       12  Atascosa
# 2                        1  Atascosa
# 3                        1  Atascosa
# 4                        1  Atascosa
# ...                    ...       ...
# 3626206                  1    Wilson
# 3626207                  1    Wilson
# 3626208                  1    Wilson
# 3626209                  1    Wilson
# 3626210                  1    Wilson
#
#                                                   locality   latitude  \
# 0                                              Peeler Tank  28.735340
# 1                                              Peeler Tank  28.735340
# 2                        Atascosa Co.--CR411/412 FM99 area  28.710839
# 3                        Atascosa Co.--CR411/412 FM99 area  28.710839
# 4                                              Peeler Tank  28.735340
# ...                                                    ...        ...
# 3626206                             Floresville River Park  29.112988
# 3626207                                      Stockdale WTP  29.231437
# 3626208                     Jackson Nature Pk (Wilson Co.)  29.219489
# 3626209                             Floresville River Park  29.112988
# 3626210  County Road 228, Falls City US-TX (29.0861,-97...  29.086134
#
#          longitude observation_date time_observations_started observer_id  \
# 0       -98.435998       2002-01-05                       NaN   obsr88598
# 1       -98.435998       2002-01-05                       NaN   obsr88598
# 2       -98.214340       2002-01-11                  14:35:00   obsr21142
# 3       -98.214340       2002-01-11                  14:35:00   obsr21142
# 4       -98.435998       2002-01-05                       NaN   obsr88598
# ...            ...              ...                       ...         ...
# 3626206 -98.171639       2019-05-03                  15:00:00  obsr280995
# 3626207 -97.977619       2019-05-03                  11:07:00  obsr172206
# 3626208 -98.009613       2019-05-03                  11:54:00  obsr172206
# 3626209 -98.171639       2019-05-03                  15:06:00   obsr30058
# 3626210 -97.984804       2019-05-05                  15:46:00  obsr419944
#
#         sampling_event_identifier  duration_minutes  effort_distance_km  \
# 0                        S5554748               NaN                 NaN
# 1                        S5554748               NaN                 NaN
# 2                       S17226909              50.0               1.609
# 3                       S17226909              50.0               1.609
# 4                        S5554748               NaN                 NaN
# ...                           ...               ...                 ...
# 3626206                 S55963999              60.0               3.219
# 3626207                 S55715622              27.0                 NaN
# 3626208                 S55724322             113.0               2.253
# 3626209                 S55827344              60.0               1.609
# 3626210                 S55873307              36.0               0.773
#
#          number_observers  all_species_reported
# 0                     NaN                     1
# 1                     NaN                     1
# 2                     2.0                     1
# 3                     2.0                     1
# 4                     NaN                     1
# ...                   ...                   ...
# 3626206              13.0                     1
# 3626207              13.0                     1
# 3626208              13.0                     1
# 3626209              13.0                     1
# 3626210               2.0                     1
#
# [3626211 rows x 16 columns]

# %%
dff['month'] = dff.observation_date.str[5:7]
dff['year'] = dff.observation_date.str[:4]

# %%
dff.year.unique()
# Out:
# array(['2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020', '2021', '2022', '2023'], dtype=object)

# %%
dff.year.nunique()
# Out:
# 22

# %%
round(dff [dff.county == 'Bexar'].groupby('month').sampling_event_identifier.nunique() / dff.year.nunique(),0)
# Out:
# month
# 01    680.0
# 02    604.0
# 03    685.0
# 04    809.0
# 05    692.0
# 06    366.0
# 07    329.0
# 08    348.0
# 09    437.0
# 10    439.0
# 11    440.0
# 12    530.0
# Name: sampling_event_identifier, dtype: float64

# %%
dff
# Out:
#          taxonomic_order category                   common_name  \
# 0                  11791  species              American Kestrel
# 1                    233  species  Black-bellied Whistling-Duck
# 2                  33307  species          Brown-headed Cowbird
# 3                  33325  species            Brewer's Blackbird
# 4                   8416  species                      Barn Owl
# ...                  ...      ...                           ...
# 3626206            34060  species                Indigo Bunting
# 3626207            34060  species                Indigo Bunting
# 3626208             5798  species                      Killdeer
# 3626209             5798  species                      Killdeer
# 3626210             5798  species                      Killdeer
#
#          observation_count    county  \
# 0                        1  Atascosa
# 1                       12  Atascosa
# 2                        1  Atascosa
# 3                        1  Atascosa
# 4                        1  Atascosa
# ...                    ...       ...
# 3626206                  1    Wilson
# 3626207                  1    Wilson
# 3626208                  1    Wilson
# 3626209                  1    Wilson
# 3626210                  1    Wilson
#
#                                                   locality   latitude  \
# 0                                              Peeler Tank  28.735340
# 1                                              Peeler Tank  28.735340
# 2                        Atascosa Co.--CR411/412 FM99 area  28.710839
# 3                        Atascosa Co.--CR411/412 FM99 area  28.710839
# 4                                              Peeler Tank  28.735340
# ...                                                    ...        ...
# 3626206                             Floresville River Park  29.112988
# 3626207                                      Stockdale WTP  29.231437
# 3626208                     Jackson Nature Pk (Wilson Co.)  29.219489
# 3626209                             Floresville River Park  29.112988
# 3626210  County Road 228, Falls City US-TX (29.0861,-97...  29.086134
#
#          longitude observation_date time_observations_started observer_id  \
# 0       -98.435998       2002-01-05                       NaN   obsr88598
# 1       -98.435998       2002-01-05                       NaN   obsr88598
# 2       -98.214340       2002-01-11                  14:35:00   obsr21142
# 3       -98.214340       2002-01-11                  14:35:00   obsr21142
# 4       -98.435998       2002-01-05                       NaN   obsr88598
# ...            ...              ...                       ...         ...
# 3626206 -98.171639       2019-05-03                  15:00:00  obsr280995
# 3626207 -97.977619       2019-05-03                  11:07:00  obsr172206
# 3626208 -98.009613       2019-05-03                  11:54:00  obsr172206
# 3626209 -98.171639       2019-05-03                  15:06:00   obsr30058
# 3626210 -97.984804       2019-05-05                  15:46:00  obsr419944
#
#         sampling_event_identifier  duration_minutes  effort_distance_km  \
# 0                        S5554748               NaN                 NaN
# 1                        S5554748               NaN                 NaN
# 2                       S17226909              50.0               1.609
# 3                       S17226909              50.0               1.609
# 4                        S5554748               NaN                 NaN
# ...                           ...               ...                 ...
# 3626206                 S55963999              60.0               3.219
# 3626207                 S55715622              27.0                 NaN
# 3626208                 S55724322             113.0               2.253
# 3626209                 S55827344              60.0               1.609
# 3626210                 S55873307              36.0               0.773
#
#          number_observers  all_species_reported month  year
# 0                     NaN                     1    01  2002
# 1                     NaN                     1    01  2002
# 2                     2.0                     1    01  2002
# 3                     2.0                     1    01  2002
# 4                     NaN                     1    01  2002
# ...                   ...                   ...   ...   ...
# 3626206              13.0                     1    05  2019
# 3626207              13.0                     1    05  2019
# 3626208              13.0                     1    05  2019
# 3626209              13.0                     1    05  2019
# 3626210               2.0                     1    05  2019
#
# [3626211 rows x 18 columns]

# %%
df_species = dff [dff.category == 'species']

# %%
for county in df_species.county.unique():
    print()
    print(county)
    print('-----')
    subset = df_species [df_species.county == county]
    
    all_species = []
    
    for year in subset.year.unique():
        this_year_species = subset [subset.year == year].common_name.unique()
        all_species.extend(this_year_species)

    all_species = pd.Series(all_species)
    year_all = all_species.value_counts() [all_species.value_counts() == 22].index
    year_one = all_species.value_counts() [all_species.value_counts() == 1].index
    
#     for year in subset.year.unique():
#         this_year_species = subset [subset.year == year].common_name.unique()
#         print(f'{year}')
#         year_one_species = np.intersect1d(year_one, this_year_species)
#         if len(year_one_species) > 0:
#             for species in year_one_species:
#                 print(f'  {species}')
    print('all years')
    print(year_all)
# Out:
# Atascosa
# -----
# all years
# Index([], dtype='object')
#
# Bandera
# -----
# all years
# Index(['American Kestrel', 'Blue Grosbeak', 'Northern Mockingbird',
#        'Nashville Warbler', 'Louisiana Waterthrush', 'Lincoln's Sparrow',
#        'Lesser Goldfinch', 'Lark Sparrow', 'Indigo Bunting', 'House Wren',
#        'Hermit Thrush', 'Green Kingfisher', 'Golden-fronted Woodpecker',
#        'Field Sparrow', 'Eastern Wood-Pewee', 'Eastern Screech-Owl',
#        'Cooper's Hawk', 'Cliff Swallow', 'Clay-colored Sparrow',
#        'Cedar Waxwing', 'Canyon Towhee', 'Bushtit',
#        'Black-throated Green Warbler', 'Belted Kingfisher',
#        'Yellow-throated Warbler', 'Northern Rough-winged Swallow',
#        'Purple Martin', 'American Robin', 'Zone-tailed Hawk',
#        'Yellow-billed Cuckoo', 'Woodhouse's Scrub-Jay', 'Wilson's Warbler',
#        'Wild Turkey', 'White-crowned Sparrow', 'Cave Swallow',
#        'Vermilion Flycatcher', 'Summer Tanager', 'Olive Sparrow',
#        'Spotted Towhee', 'Sharp-shinned Hawk', 'Scissor-tailed Flycatcher',
#        'Scott's Oriole', 'Painted Bunting', 'Ruby-throated Hummingbird',
#        'Red-winged Blackbird', 'Red-eyed Vireo', 'Orange-crowned Warbler',
#        'Brown-headed Cowbird', 'Bronzed Cowbird', 'Eastern Phoebe',
#        'Ladder-backed Woodpecker', 'Canyon Wren', 'Great-tailed Grackle',
#        'Golden-cheeked Warbler', 'Carolina Wren', 'Carolina Chickadee',
#        'Blue-gray Gnatcatcher', 'Eastern Bluebird', 'Black-crested Titmouse',
#        'Black-chinned Hummingbird', 'Chipping Sparrow',
#        'Black-and-white Warbler', 'Northern Cardinal',
#        'Ash-throated Flycatcher', 'Rufous-crowned Sparrow',
#        'Yellow-rumped Warbler', 'Ruby-crowned Kinglet', 'Red-tailed Hawk',
#        'Red-shouldered Hawk', 'Common Raven', 'Mourning Dove', 'Black Vulture',
#        'House Finch', 'Bell's Vireo', 'American Goldfinch',
#        'Acadian Flycatcher', 'Yellow-throated Vireo', 'Great Blue Heron',
#        'Inca Dove', 'Bewick's Wren', 'Greater Roadrunner', 'Barn Swallow',
#        'White-winged Dove', 'European Starling', 'White-eyed Vireo',
#        'Turkey Vulture', 'Black-capped Vireo', 'House Sparrow'],
#       dtype='object')
#
# Bexar
# -----
# all years
# Index(['American Crow', 'Bullock's Oriole', 'Black-chinned Hummingbird',
#        'Chimney Swift', 'Couch's Kingbird', 'Eurasian Collared-Dove',
#        'Golden-cheeked Warbler', 'Grasshopper Sparrow', 'Green Kingfisher',
#        'Lark Sparrow',
#        ...
#        'Lesser Scaup', 'Lesser Yellowlegs', 'Ladder-backed Woodpecker',
#        'Lincoln's Sparrow', 'Least Grebe', 'Least Sandpiper', 'Inca Dove',
#        'Long-billed Thrasher', 'Harris's Hawk', 'Sharp-shinned Hawk'],
#       dtype='object', length=205)
#
# Comal
# -----
# all years
# Index(['American Crow', 'Ruby-crowned Kinglet', 'Red-tailed Hawk',
#        'Ring-necked Duck', 'Savannah Sparrow', 'Turkey Vulture',
#        'Vesper Sparrow', 'Woodhouse's Scrub-Jay', 'Yellow-rumped Warbler',
#        'Belted Kingfisher', 'Blue Jay', 'Inca Dove', 'Red-shouldered Hawk',
#        'Red-winged Blackbird', 'Ring-billed Gull', 'American Goldfinch',
#        'Northern Mockingbird', 'Black-and-white Warbler', 'Barred Owl',
#        'Canyon Wren', 'Downy Woodpecker', 'House Finch', 'House Sparrow',
#        'White-eyed Vireo', 'Summer Tanager', 'Blue-gray Gnatcatcher',
#        'Scissor-tailed Flycatcher', 'Yellow-billed Cuckoo',
#        'White-winged Dove', 'Yellow-crowned Night Heron',
#        'Orange-crowned Warbler', 'Lincoln's Sparrow', 'Northern Cardinal',
#        'Carolina Wren', 'Gadwall', 'Field Sparrow', 'Eastern Phoebe',
#        'Double-crested Cormorant', 'Common Raven', 'Chipping Sparrow',
#        'Carolina Chickadee', 'Great Blue Heron', 'Bufflehead',
#        'Brown-headed Cowbird', 'Black Vulture', 'Black-crested Titmouse',
#        'American Wigeon', 'American Kestrel', 'Golden-fronted Woodpecker',
#        'Bewick's Wren', 'Mourning Dove', 'Killdeer',
#        'Ladder-backed Woodpecker', 'Mallard', 'Loggerhead Shrike'],
#       dtype='object')
#
# Gillespie
# -----
# all years
# Index(['Ruby-crowned Kinglet', 'Great Blue Heron', 'Great-tailed Grackle',
#        'House Finch', 'House Sparrow', 'American Goldfinch', 'Killdeer',
#        'Ladder-backed Woodpecker', 'Mourning Dove', 'Northern Cardinal',
#        'Vesper Sparrow', 'Northern Mockingbird', 'Spotted Towhee',
#        'Red-winged Blackbird', 'Red-shouldered Hawk', 'Red-tailed Hawk',
#        'Purple Martin', 'Inca Dove', 'Turkey Vulture', 'White-crowned Sparrow',
#        'White-winged Dove', 'Woodhouse's Scrub-Jay', 'Yellow-rumped Warbler',
#        'Carolina Wren', 'Brown-headed Cowbird', 'Belted Kingfisher',
#        'Wild Turkey', 'Blue Jay', 'Chipping Sparrow',
#        'Scissor-tailed Flycatcher', 'Black Vulture', 'Black-crested Titmouse',
#        'Bewick's Wren', 'American Robin', 'American Kestrel',
#        'Loggerhead Shrike', 'Eastern Phoebe', 'Eurasian Collared-Dove',
#        'Golden-fronted Woodpecker', 'Field Sparrow', 'Lark Sparrow',
#        'Carolina Chickadee'],
#       dtype='object')
#
# Guadalupe
# -----
# all years
# Index(['American Crow', 'European Starling', 'Killdeer', 'Sharp-shinned Hawk',
#        'White-crowned Sparrow', 'American Goldfinch',
#        'Black-and-white Warbler', 'Black-chinned Hummingbird',
#        'Black-crested Titmouse', 'Blue-gray Gnatcatcher', 'Carolina Wren',
#        'Greater Roadrunner', 'House Finch', 'Lincoln's Sparrow',
#        'Northern Cardinal', 'Orange-crowned Warbler', 'Ruby-crowned Kinglet',
#        'White-eyed Vireo', 'White-winged Dove', 'Yellow-rumped Warbler',
#        'American Redstart', 'Blackburnian Warbler',
#        'Black-throated Green Warbler', 'Western Cattle Egret',
#        'Chestnut-sided Warbler', 'Common Ground Dove', 'Lesser Goldfinch',
#        'Painted Bunting', 'Purple Martin', 'Scissor-tailed Flycatcher',
#        'American Kestrel', 'Inca Dove', 'Magnolia Warbler',
#        'Brown-headed Cowbird', 'Red-tailed Hawk', 'Black Vulture',
#        'Great Blue Heron', 'Great Egret', 'Carolina Chickadee',
#        'Great-tailed Grackle', 'House Sparrow', 'Loggerhead Shrike',
#        'Eastern Phoebe', 'Northern Mockingbird', 'Mourning Dove',
#        'Vesper Sparrow', 'Savannah Sparrow', 'Turkey Vulture'],
#       dtype='object')
#
# Kendall
# -----
# all years
# Index(['Carolina Chickadee', 'Killdeer', 'House Finch', 'House Sparrow',
#        'Loggerhead Shrike', 'Northern Cardinal', 'Northern Mockingbird',
#        'Red-shouldered Hawk', 'Scissor-tailed Flycatcher', 'White-winged Dove',
#        'Yellow-billed Cuckoo', 'American Kestrel', 'American Robin',
#        'European Starling', 'Golden-fronted Woodpecker', 'Lesser Scaup',
#        'Great Crested Flycatcher', 'Pied-billed Grebe',
#        'Yellow-rumped Warbler', 'American Goldfinch', 'Chipping Sparrow',
#        'Common Raven', 'Eastern Bluebird', 'Ladder-backed Woodpecker',
#        'Lincoln's Sparrow', 'Northern Bobwhite', 'Orange-crowned Warbler',
#        'Savannah Sparrow', 'Spotted Towhee', 'Ruby-crowned Kinglet',
#        'Green Heron', 'Field Sparrow', 'Black-crested Titmouse',
#        'Turkey Vulture', 'Barn Swallow', 'Carolina Wren', 'Eastern Phoebe',
#        'Mourning Dove', 'Woodhouse's Scrub-Jay', 'Eastern Meadowlark',
#        'Ruddy Duck', 'Summer Tanager', 'Inca Dove', 'Black Vulture',
#        'White-eyed Vireo', 'Lark Sparrow', 'Bewick's Wren',
#        'Black-bellied Whistling-Duck', 'Black-chinned Hummingbird',
#        'Brown-headed Cowbird', 'Lesser Goldfinch', 'Purple Martin',
#        'Chimney Swift'],
#       dtype='object')
#
# Kerr
# -----
# all years
# Index(['Greater Roadrunner', 'Black-capped Vireo', 'Woodhouse's Scrub-Jay',
#        'Vermilion Flycatcher', 'Summer Tanager', 'Red-tailed Hawk',
#        'Painted Bunting', 'Nashville Warbler', 'Ladder-backed Woodpecker',
#        'Indigo Bunting', 'Green Kingfisher', 'Golden-fronted Woodpecker',
#        'Golden-cheeked Warbler', 'Common Grackle', 'Clay-colored Sparrow',
#        'Cave Swallow', 'Canyon Wren', 'Canyon Towhee', 'Blue Jay',
#        'Yellow-billed Cuckoo', 'Black-chinned Hummingbird', 'Chimney Swift',
#        'Dark-eyed Junco', 'Vesper Sparrow', 'Bald Eagle', 'House Wren',
#        'Mallard', 'Spotted Sandpiper', 'Eastern Meadowlark',
#        'Northern Flicker', 'American Robin', 'Cliff Swallow',
#        'Western Kingbird', 'American Kestrel', 'Red-winged Blackbird',
#        'Red-shouldered Hawk', 'House Sparrow', 'Great-tailed Grackle',
#        'Great Blue Heron', 'Blue Grosbeak', 'Savannah Sparrow', 'Bell's Vireo',
#        'Ash-throated Flycatcher', 'White-winged Dove',
#        'Orange-crowned Warbler', 'Barn Swallow', 'Eastern Phoebe',
#        'Common Raven', 'Bewick's Wren', 'Yellow-rumped Warbler',
#        'Turkey Vulture', 'Ruby-crowned Kinglet', 'Northern Cardinal',
#        'Inca Dove', 'House Finch', 'Hermit Thrush', 'European Starling',
#        'Chipping Sparrow', 'Carolina Chickadee', 'Black Vulture',
#        'Black-crested Titmouse', 'Belted Kingfisher', 'Zone-tailed Hawk',
#        'Lesser Goldfinch', 'White-eyed Vireo', 'Mourning Dove',
#        'Loggerhead Shrike', 'Northern Mockingbird', 'Rufous-crowned Sparrow',
#        'Lincoln's Sparrow', 'Scissor-tailed Flycatcher', 'Lark Sparrow',
#        'Field Sparrow', 'Eastern Bluebird', 'Northern Bobwhite',
#        'Cedar Waxwing', 'Carolina Wren', 'Wild Turkey',
#        'Blue-gray Gnatcatcher'],
#       dtype='object')
#
# Medina
# -----
# all years
# Index(['Turkey Vulture', 'House Sparrow', 'Great-tailed Grackle',
#        'Western Kingbird', 'European Starling', 'White-winged Dove',
#        'White-eyed Vireo', 'Ruby-crowned Kinglet', 'Red-winged Blackbird',
#        'Purple Martin', 'Northern Cardinal', 'Mourning Dove',
#        'Ladder-backed Woodpecker', 'Inca Dove', 'Northern Mockingbird',
#        'Scissor-tailed Flycatcher', 'Carolina Wren', 'Great Blue Heron',
#        'Golden-fronted Woodpecker', 'Belted Kingfisher', 'Eastern Phoebe',
#        'Black-crested Titmouse', 'Black Vulture', 'Carolina Chickadee'],
#       dtype='object')
#
# Wilson
# -----
# all years
# Index([], dtype='object')
